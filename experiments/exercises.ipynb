# %%
import json
import os
file_path="../public/orthoData.json"
with open(file_path, "r", encoding="utf-8") as f:
    ortho_data = json.load(f)

tooth_id = 16
landmarks_0_ = ortho_data["Staging"][0]["Landmarks"].get(str(tooth_id), {})
landmarks_0_
# Out:
# {'MDWLine': {'start': {'x': '-5.0194495560772339',
#    'y': '-3.206424185146671',
#    'z': '7.5517422417391504'},
#   'end': {'x': '5.2346795903603045',
#    'y': '-2.532675083881271',
#    'z': '7.5517422417391504'}},
#  'BCPoint': {'x': '-3.5506279706467123',
#   'y': '-2.8118167419835647',
#   'z': '7.3235440582504161'},
#  'MRAPoint': {'x': '0', 'y': '0', 'z': '-11.020723187420813'},
#  'FEGJPoint': {'x': '0.060279612285904213',
#   'y': '-5.3249484056819947',
#   'z': '1.2338108726878376'},
#  'BRLine': {'start': {'x': '-4.292444344647075',
#    'y': '-3.4120646985722991',
#    'z': '6.8781353322037413'},
#   'end': {'x': '4.4301512708597048',
#    'y': '-3.5829329509050183',
#    'z': '6.8781353322037413'}}}
